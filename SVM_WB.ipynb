# %%
# %pylab inline

import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from pprint import pprint

import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## SVM

# %%
X1, Y1 = datasets.make_classification(n_features=2, n_redundant=0, n_informative=1,
                             n_clusters_per_class=1, random_state=15)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1, cmap=plt.cm.Paired)

# %%
# %%timeit

# fit the model and get the separating hyperplane (be patient)
clf = SVC(kernel='linear', C=10000000)
# Out:
# 100000 loops, best of 3: 2.93 µs per loop

# %%
# %%timeit
clf_1mill.fit(X1, Y1)
# Out:
# 100000000 loops, best of 3: 15.6 ns per loop

# %%
clf_1 = SVC(kernel='linear', C=0.004)
clf_1.fit(X1, Y1)
# Out:
# SVC(C=0.004, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.0, kernel='linear', max_iter=-1, probability=False,
#   random_state=None, shrinking=True, tol=0.001, verbose=False)

# %%
#w = clf_1mill.coef_[0] - ipython refusing to remember the object
w = SVC(kernel='linear', C=10000000).fit(X1, Y1).coef_[0] 
a = -w[0] / w[1]
xx = np.linspace(-5, 5)
yy = a * xx - SVC(kernel='linear', C=10000000).fit(X1, Y1).intercept_[0] / w[1]

# plot separating hyperplanes and samples
h0 = plt.plot(xx, yy, 'k-', label='C = 10^7')
plt.scatter(X1[:, 0], X1[:, 1], c=Y1, cmap=plt.cm.Paired)
plt.legend()

plt.axis('tight')
# Out:
# (-5.5, 5.5, -2.2543373478352171, 1.2985891085956505)

# %%
X2, Y2 = datasets.make_classification(n_features=2, n_redundant=0, n_informative=2,
                             n_clusters_per_class=1, weights=[0.2, 0.8], random_state=12)

plt.scatter(X2[:, 0], X2[:, 1], marker='o', c=Y2, cmap=plt.cm.Paired)

# %%
X3, Y3 = datasets.make_classification(n_samples = 10000,n_features=2, n_redundant=0, n_informative=2,
                             n_clusters_per_class=1, weights=[0.1], random_state=48)

plt.scatter(X3[:, 0], X3[:, 1], marker='o', c=Y3, cmap=plt.cm.Paired)
